# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def funcion(x,y):
    return x**2 +2*x- y**2

def derxf(x):
    return 2*x+2
def deryf(y):
    return -2*y
def derzf(z):
    return 0

a=np.array([1,1,3])


x=np.linspace(-4,4,100)
y=np.linspace(-4,4,100)
X, Y = np.meshgrid(x, y)

def taylor(X,Y,z):
    return 4*X-2*Y

ax = plt.figure().add_subplot(projection='3d')


ax.plot_surface(X, Y, taylor(X,Y,0), color='royalblue',alpha=0.5)
ax.plot_surface(X, Y, funcion(X,Y), color='lightgray',alpha=0.5)
ax.scatter(1,1,2,color="red", marker="o")

#ax.set_aspect('equal')
ax.set_zlim(-4, 4)
plt.show()
