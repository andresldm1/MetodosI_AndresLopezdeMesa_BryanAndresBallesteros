# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 1

# %%
def Casos_Favorables(n):
    r = ((365-n)/365)
    return r

# %%
Prob = 1
D = []
for i in range(1,81):
    n = i
    Prob = Prob*Casos_Favorables(n)#Probabilidad conjunta de que no cumplan el mismo día
    D.append(1- Prob)

# %%
x = np.linspace(1,81,80)
plt.title("Probabilidad en función del número de personas")
plt.ylabel("P(n)")
plt.xlabel("n")
plt.plot(x,dist)
